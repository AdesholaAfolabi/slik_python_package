# %%
from slik import loadfile as lf

# %%
train = lf.read_file('/opt/notebooks/data/train.csv')
# Out:
# CSV file read sucessfully
#
# Data has 891 rows and 12 columns

# %%
from slik import preprocessing as pp

# %%
pp.identify_columns(train,'Survived')
# Out:
#  Name has a high cardinality. It has 891 unique attributes
#
#  Ticket has a high cardinality. It has 681 unique attributes
#
#  Cabin has a high cardinality. It has 147 unique attributes
#
# ------------------------- Saving Attributes in Yaml file -------------------------
#
#
# Done!. Data columns successfully identified and attributes are stored in data/

# %%
pp.map_column(train,column_name='Sex',items={'male':1,'female':0})

# %%
dataw = pp.detect_outliers(train,y='Survived',n=2,remove=True)

# %%
pp.check_nan(train,plot=True)
# Out:
# ------------------------- Count and Percentage of missing value -------------------------

# %%
data = pp.handle_nan(dataframe=train,target_name='Survived',strategy='mode',fillna='missing',
                     drop_outliers=True,thresh_x=75,thresh_y=80)
# Out:
# Missing Columns with 80% missing value : []
#
# New data shape is (891, 12)
#
# ------------------------- Table idenifying Outliers present -------------------------
#      PassengerId  Survived  Pclass                               Name  Sex  \
# 745          746         0       1       Crosby, Capt. Edward Gifford    1
# 27            28         0       1     Fortune, Mr. Charles Alexander    1
# 88            89         1       1         Fortune, Miss. Mabel Helen    0
# 159          160         0       3         Sage, Master. Thomas Henry    1
# 180          181         0       3       Sage, Miss. Constance Gladys    0
# 201          202         0       3                Sage, Mr. Frederick    1
# 324          325         0       3           Sage, Mr. George John Jr    1
# 341          342         1       1     Fortune, Miss. Alice Elizabeth    0
# 792          793         0       3            Sage, Miss. Stella Anna    0
# ...
